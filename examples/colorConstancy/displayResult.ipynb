# %%
import os
os.chdir('../../')
import numpy as np
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
loss_1 = np.load('models/color_constancy/result/loss_1.npy')
plot(np.vstack([loss_1]).clip(0, 10).T)

loss_1 = np.load('models/color_constancy/result/loss_1_with_FC9.npy')
plot(np.vstack([loss_1]).clip(0, 10).T)
